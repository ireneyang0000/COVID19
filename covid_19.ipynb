# %%
import pandas as pd

# %%
covid_19_train = pd.read_csv('/Users/lima/Desktop/DS/covid19-global-forecasting-week-5/train.csv',
                                 sep=',', delimiter=None, header='infer')
covid_19_submission = pd.read_csv('/Users/lima/Desktop/DS/covid19-global-forecasting-week-5/submission.csv',
                                 sep=',', delimiter=None, header='infer')
covid_19_test = pd.read_csv('/Users/lima/Desktop/DS/covid19-global-forecasting-week-5/test.csv',
                                 sep=',', delimiter=None, header='infer')
covid_19_mob_trend = pd.read_csv('/Users/lima/Desktop/DS/covid19-global-forecasting-week-5/datasets_618801_1126290_applemobilitytrends-2020-05-01.csv',
                                 sep=',', delimiter=None, header='infer')

# %%
covid_19_train.head()
# Out:
#    Id County Province_State Country_Region  Population    Weight        Date  \
# 0   1    NaN            NaN    Afghanistan    27657145  0.058359  2020-01-23
# 1   2    NaN            NaN    Afghanistan    27657145  0.583587  2020-01-23
# 2   3    NaN            NaN    Afghanistan    27657145  0.058359  2020-01-24
# 3   4    NaN            NaN    Afghanistan    27657145  0.583587  2020-01-24
# 4   5    NaN            NaN    Afghanistan    27657145  0.058359  2020-01-25
#
#            Target  TargetValue
# 0  ConfirmedCases          0.0
# 1      Fatalities          0.0
# 2  ConfirmedCases          0.0
# 3      Fatalities          0.0
# 4  ConfirmedCases          0.0

# %%
covid_19_submission.head()
# Out:
#   ForecastId_Quantile  TargetValue
# 0              1_0.05            1
# 1               1_0.5            1
# 2              1_0.95            1
# 3              2_0.05            1
# 4               2_0.5            1

# %%
covid_19_test.head()
# Out:
#    ForecastId County Province_State Country_Region  Population    Weight  \
# 0           1    NaN            NaN    Afghanistan    27657145  0.058359
# 1           2    NaN            NaN    Afghanistan    27657145  0.583587
# 2           3    NaN            NaN    Afghanistan    27657145  0.058359
# 3           4    NaN            NaN    Afghanistan    27657145  0.583587
# 4           5    NaN            NaN    Afghanistan    27657145  0.058359
#
#          Date          Target
# 0  2020-04-27  ConfirmedCases
# 1  2020-04-27      Fatalities
# 2  2020-04-28  ConfirmedCases
# 3  2020-04-28      Fatalities
# 4  2020-04-29  ConfirmedCases

# %%
covid_19_mob_trend.head()
# Out:
#          geo_type     region transportation_type alternative_name  2020-01-13  \
# 0  country/region    Albania             driving              NaN       100.0
# 1  country/region    Albania             walking              NaN       100.0
# 2  country/region  Argentina             driving              NaN       100.0
# 3  country/region  Argentina             walking              NaN       100.0
# 4  country/region  Australia             driving              NaN       100.0
#
#    2020-01-14  2020-01-15  2020-01-16  2020-01-17  2020-01-18  ...  \
# 0       95.30      101.43       97.20      103.55      112.67  ...
# 1      100.68       98.93       98.46      100.85      100.13  ...
# 2       97.07      102.45      111.21      118.45      124.01  ...
# 3       95.11      101.37      112.67      116.72      114.14  ...
# 4      102.98      104.21      108.63      109.08       89.00  ...
#
#    2020-04-22  2020-04-23  2020-04-24  2020-04-25  2020-04-26  2020-04-27  \
# ...

# %%
covid_19_train.describe()
# Out:
#        2020-01-13   2020-01-14   2020-01-15   2020-01-16   2020-01-17  \
# count      1119.0  1119.000000  1119.000000  1119.000000  1119.000000
# mean        100.0   101.877909   104.408534   106.698097   121.441868
# std           0.0     5.900194     7.948394     8.902700    18.394967
# min         100.0    32.720000    26.490000    32.190000    29.390000
# 25%         100.0    99.210000   101.020000   102.375000   110.690000
# 50%         100.0   101.840000   104.230000   106.180000   120.600000
# 75%         100.0   104.570000   107.490000   110.285000   130.580000
# max         100.0   138.260000   206.160000   182.180000   218.200000
#
#         2020-01-18   2020-01-19   2020-01-20   2020-01-21   2020-01-22  ...  \
# count  1119.000000  1119.000000  1119.000000  1119.000000  1119.000000  ...
# mean    121.377399   100.674433   101.784254   103.329026   104.463432  ...
# std      26.397309    19.452300    10.757007    13.854440    13.551606  ...
# ...

# %%
descriptive_for_region = 
covid_19_train.groupby(['Country_Region','Target'])['Country_Region','Target','Population'].sum()

# %%
descriptive_for_region.sort_values(['Population'])
# Out:
#                                    Population
# Country_Region   Target
# Holy See         Fatalities             58179
#                  ConfirmedCases         58179
# Diamond Princess ConfirmedCases        478719
#                  Fatalities            478719
# San Marino       ConfirmedCases       4257645
# ...                                       ...
# US               Fatalities      126899822595
# India            ConfirmedCases  167082090000
#                  Fatalities      167082090000
# China            ConfirmedCases  360109537200
#                  Fatalities      360109537200
#
# [374 rows x 1 columns]
